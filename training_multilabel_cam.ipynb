# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATA_PATH = '/content/drive/MyDrive/domain-helper/'
LOG_PATH = '/content/drive/MyDrive/domain-helper/logs/'

# !pip install -q transformers datasets nlp

from nlp import load_dataset, DatasetDict



dataset = load_dataset('csv', data_files=[str(DATA_PATH) + '/gar_level_labeled_data.csv'], split='train' )

# 90% train, 10% test + validation
train_test_valid = dataset.train_test_split(test_size=0.1)
# Split the 10% test + valid in half test, half valid
test_valid = train_test_valid['test'].train_test_split(test_size=0.5)
# gather everyone if you want to have a single DatasetDict
dataset = DatasetDict({
    'train': train_test_valid['train'],
    'test': test_valid['test'],
    'validation': test_valid['train']})

labels = [label for label in dataset['train'].features.keys() if label not in ['id', 'text']]
id2label = {idx:label for idx, label in enumerate(labels)}
label2id = {label:idx for idx, label in enumerate(labels)}
# Out:
# Using custom data configuration default

# %%
from transformers import CamembertTokenizerFast
import numpy as np

tokenizer = CamembertTokenizerFast.from_pretrained("camembert-base")

def preprocess_data(examples):
  titles = examples["text"]
  #auto max length is set to 62, but most examples dont exceed 30. Force max length parameter ?
  encoding = tokenizer(titles, padding=True, truncation=True)#, max_length=36)
  labels_batch = {k: examples[k] for k in examples.keys() if k in labels}
  labels_matrix = np.zeros((len(titles), len(labels)))
  for idx, label in enumerate(labels):
    labels_matrix[:, idx] = labels_batch[label]
  encoding["labels"] = labels_matrix.tolist()
  return encoding

# %%
encoded_dataset = dataset.map(preprocess_data, batched=True, remove_columns=dataset['train'].column_names)
encoded_dataset.set_format("torch")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from transformers import CamembertForSequenceClassification

model = CamembertForSequenceClassification.from_pretrained("camembert-base", 
                                                           problem_type="multi_label_classification", 
                                                           num_labels=len(labels),
                                                           id2label=id2label,
                                                           label2id=label2id)
# Out:
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.bias', 'roberta.pooler.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.dense.weight', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing CamembertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of CamembertForSequenceClassification were not initialized from the model checkpoint at camembert-base and are newly initialized: ['classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
metric_name = "f1"
batch_size = 20
epochs = 100
weight_decay = 0.01

from transformers import TrainingArguments, Trainer

args = TrainingArguments(
    output_dir=f'{DATA_PATH}/level-results-2',
    evaluation_strategy = "epoch",
    save_strategy = "epoch",
    learning_rate=1e-5,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=epochs,
    weight_decay=weight_decay,
    load_best_model_at_end=True,
    metric_for_best_model=metric_name
)

# %%
from sklearn.metrics import f1_score, roc_auc_score, accuracy_score
from transformers import EvalPrediction
import torch
    
# source: https://jesusleal.io/2021/04/21/Longformer-multilabel-classification/
def multi_label_metrics(predictions, labels, threshold=0.5):
    # first, apply sigmoid on predictions which are of shape (batch_size, num_labels)
    sigmoid = torch.nn.Sigmoid()
    probs = sigmoid(torch.Tensor(predictions))
    # next, use threshold to turn them into integer predictions
    y_pred = np.zeros(probs.shape)
    y_pred[np.where(probs >= threshold)] = 1
    # finally, compute metrics
    y_true = labels
    f1_micro_average = f1_score(y_true=y_true, y_pred=y_pred, average='micro')
    roc_auc = roc_auc_score(y_true, y_pred, average = 'micro')
    accuracy = accuracy_score(y_true, y_pred)
    # return as dictionary
    metrics = {'f1': f1_micro_average,
               'roc_auc': roc_auc,
               'accuracy': accuracy}
    return metrics

def compute_metrics(p: EvalPrediction):
    preds = p.predictions[0] if isinstance(p.predictions, 
            tuple) else p.predictions
    result = multi_label_metrics(
        predictions=preds, 
        labels=p.label_ids)
    return result

# %%
trainer = Trainer(
    model,
    args,
    train_dataset=encoded_dataset["train"],
    eval_dataset=encoded_dataset["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 8552
#   Num Epochs = 100
#   Instantaneous batch size per device = 20
#   Total train batch size (w. parallel, distributed & accumulation) = 20
#   Gradient Accumulation steps = 1
#   Total optimization steps = 42800
#     <div>
#
#       <progress value='42800' max='42800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [42800/42800 2:28:45, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#       <th>Roc Auc</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.189332</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.368300</td>
#       <td>0.152455</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.155200</td>
#       <td>0.146951</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.142700</td>
#       <td>0.137820</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.130700</td>
#       <td>0.128405</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.118700</td>
#       <td>0.121474</td>
#       <td>0.222830</td>
#       <td>0.563083</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.118700</td>
#       <td>0.112776</td>
#       <td>0.306011</td>
#       <td>0.596101</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.106800</td>
#       <td>0.106117</td>
#       <td>0.356471</td>
#       <td>0.615867</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.098500</td>
#       <td>0.100712</td>
#       <td>0.349847</td>
#       <td>0.610041</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.093800</td>
#       <td>0.098237</td>
#       <td>0.376846</td>
#       <td>0.622449</td>
#       <td>0.002105</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.087300</td>
#       <td>0.092179</td>
#       <td>0.426121</td>
#       <td>0.647296</td>
#       <td>0.004211</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.081700</td>
#       <td>0.086184</td>
#       <td>0.431243</td>
#       <td>0.649949</td>
#       <td>0.008421</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.076300</td>
#       <td>0.086515</td>
#       <td>0.431006</td>
#       <td>0.649933</td>
#       <td>0.002105</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.076300</td>
#       <td>0.077222</td>
#       <td>0.513418</td>
#       <td>0.693915</td>
#       <td>0.025263</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.071900</td>
#       <td>0.079443</td>
#       <td>0.510972</td>
#       <td>0.687620</td>
#       <td>0.069474</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.067700</td>
#       <td>0.077108</td>
#       <td>0.594196</td>
#       <td>0.732199</td>
#       <td>0.225263</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.064000</td>
#       <td>0.070627</td>
#       <td>0.646560</td>
#       <td>0.763918</td>
#       <td>0.237895</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.059200</td>
#       <td>0.065612</td>
#       <td>0.666036</td>
#       <td>0.771325</td>
#       <td>0.235789</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.052500</td>
#       <td>0.066188</td>
#       <td>0.682185</td>
#       <td>0.777131</td>
#       <td>0.269474</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.047300</td>
#       <td>0.059604</td>
#       <td>0.696587</td>
#       <td>0.787499</td>
#       <td>0.261053</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.047300</td>
#       <td>0.054787</td>
#       <td>0.724572</td>
#       <td>0.810420</td>
#       <td>0.286316</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.042800</td>
#       <td>0.055455</td>
#       <td>0.742499</td>
#       <td>0.819947</td>
#       <td>0.330526</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.040100</td>
#       <td>0.050826</td>
#       <td>0.773380</td>
#       <td>0.843142</td>
#       <td>0.374737</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.036900</td>
#       <td>0.052194</td>
#       <td>0.757466</td>
#       <td>0.823552</td>
#       <td>0.381053</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.034200</td>
#       <td>0.049483</td>
#       <td>0.781779</td>
#       <td>0.847897</td>
#       <td>0.406316</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.032900</td>
#       <td>0.047359</td>
#       <td>0.776903</td>
#       <td>0.842947</td>
#       <td>0.408421</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.030000</td>
#       <td>0.046643</td>
#       <td>0.797659</td>
#       <td>0.867923</td>
#       <td>0.444211</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.030000</td>
#       <td>0.044576</td>
#       <td>0.795160</td>
#       <td>0.855434</td>
#       <td>0.458947</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.028800</td>
#       <td>0.043585</td>
#       <td>0.797599</td>
#       <td>0.859187</td>
#       <td>0.471579</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.027300</td>
#       <td>0.041452</td>
#       <td>0.812527</td>
#       <td>0.866076</td>
#       <td>0.503158</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.025700</td>
#       <td>0.045257</td>
#       <td>0.803004</td>
#       <td>0.851792</td>
#       <td>0.526316</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.023700</td>
#       <td>0.042128</td>
#       <td>0.819828</td>
#       <td>0.867871</td>
#       <td>0.560000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.022500</td>
#       <td>0.040084</td>
#       <td>0.836979</td>
#       <td>0.891683</td>
#       <td>0.595789</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.022000</td>
#       <td>0.040769</td>
#       <td>0.840470</td>
#       <td>0.887088</td>
#       <td>0.642105</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.022000</td>
#       <td>0.038322</td>
#       <td>0.854530</td>
#       <td>0.897617</td>
#       <td>0.675789</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.019600</td>
#       <td>0.039852</td>
#       <td>0.849873</td>
#       <td>0.887879</td>
#       <td>0.675789</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.018700</td>
#       <td>0.038766</td>
#       <td>0.873573</td>
#       <td>0.914261</td>
#       <td>0.751579</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.017500</td>
#       <td>0.035841</td>
#       <td>0.873715</td>
#       <td>0.910961</td>
#       <td>0.757895</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.017100</td>
#       <td>0.036565</td>
#       <td>0.882591</td>
#       <td>0.921653</td>
#       <td>0.772632</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.015300</td>
#       <td>0.036795</td>
#       <td>0.877265</td>
#       <td>0.912222</td>
#       <td>0.776842</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.014700</td>
#       <td>0.036675</td>
#       <td>0.881164</td>
#       <td>0.921589</td>
#       <td>0.793684</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.014700</td>
#       <td>0.034391</td>
#       <td>0.893300</td>
#       <td>0.918449</td>
#       <td>0.810526</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.013800</td>
#       <td>0.034758</td>
#       <td>0.898208</td>
#       <td>0.927135</td>
#       <td>0.821053</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.012800</td>
#       <td>0.034677</td>
#       <td>0.897541</td>
#       <td>0.924159</td>
#       <td>0.831579</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.012000</td>
#       <td>0.033706</td>
#       <td>0.904934</td>
#       <td>0.936647</td>
#       <td>0.842105</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.011400</td>
#       <td>0.037200</td>
#       <td>0.888800</td>
#       <td>0.928188</td>
#       <td>0.823158</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.011000</td>
#       <td>0.035889</td>
#       <td>0.900651</td>
#       <td>0.928348</td>
#       <td>0.844211</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.010000</td>
#       <td>0.035283</td>
#       <td>0.906837</td>
#       <td>0.938944</td>
#       <td>0.854737</td>
#     </tr>
#     <tr>
#       <td>49</td>
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-428
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-428/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-428/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-428/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-428/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-856
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-856/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-856/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-856/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-856/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1284
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1284/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1284/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1284/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1284/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1712
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1712/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1712/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1712/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-1712/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2140
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2140/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2140/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2140/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2140/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2568
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2568/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2568/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2568/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2568/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2996
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2996/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2996/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2996/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-2996/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3424
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3424/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3424/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3424/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3424/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3852
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3852/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3852/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3852/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-3852/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4280
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4280/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4280/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4280/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4280/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4708
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4708/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4708/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4708/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-4708/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5136
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5136/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5136/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5136/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5136/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5564
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5564/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5564/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5564/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5564/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5992
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5992/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5992/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5992/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-5992/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6420
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6420/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6420/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6420/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6420/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6848
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6848/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6848/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6848/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-6848/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7276
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7276/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7276/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7276/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7276/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7704
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7704/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7704/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7704/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-7704/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8132
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8132/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8132/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8132/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8132/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8560
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8560/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8560/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8560/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8560/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8988
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8988/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8988/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8988/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-8988/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9416
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9416/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9416/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9416/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9416/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9844
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9844/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9844/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9844/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-9844/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10272
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10272/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10272/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10272/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10272/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10700
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10700/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10700/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10700/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-10700/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11128
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11128/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11128/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11128/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11128/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11556
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11556/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11556/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11556/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11556/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11984
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11984/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11984/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11984/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-11984/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12412
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12412/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12412/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12412/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12412/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12840
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12840/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12840/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12840/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-12840/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13268
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13268/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13268/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13268/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13268/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13696
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13696/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13696/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13696/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-13696/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14124
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14124/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14124/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14124/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14124/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14552
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14552/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14552/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14552/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14552/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14980
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14980/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14980/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14980/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-14980/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15408
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15408/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15408/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15408/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15408/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15836
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15836/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15836/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15836/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-15836/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16264
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16264/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16264/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16264/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16264/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16692
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16692/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16692/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16692/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-16692/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17120
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17120/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17120/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17120/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17120/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17548
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17548/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17548/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17548/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17548/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17976
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17976/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17976/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17976/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-17976/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18404
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18404/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18404/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18404/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18404/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18832
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18832/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18832/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18832/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-18832/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19260
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19260/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19260/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19260/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19260/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19688
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19688/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19688/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19688/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-19688/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20116
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20116/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20116/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20116/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20116/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20544
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20544/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20544/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20544/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20544/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20972
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20972/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20972/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20972/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-20972/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21400
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21400/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21400/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21400/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21400/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21828
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21828/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21828/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21828/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-21828/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22256
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22256/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22256/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22256/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22256/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22684
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22684/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22684/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22684/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-22684/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23112
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23112/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23112/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23112/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23112/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23540
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23540/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23540/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23540/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23540/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23968
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23968/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23968/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23968/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-23968/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24396
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24396/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24396/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24396/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24396/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24824
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24824/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24824/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24824/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-24824/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25252
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25252/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25252/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25252/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25252/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25680
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25680/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25680/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25680/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-25680/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26108
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26108/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26108/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26108/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26108/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26536
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26536/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26536/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26536/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26536/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-26964
# ...
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32528/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32528/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32956
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32956/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32956/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32956/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-32956/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33384
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33384/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33384/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33384/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33384/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33812
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33812/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33812/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33812/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-33812/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34240
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34240/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34240/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34240/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34240/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34668
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34668/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34668/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34668/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-34668/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35096
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35096/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35096/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35096/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35096/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35524
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35524/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35524/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35524/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35524/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35952
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35952/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35952/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35952/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-35952/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36380
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36380/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36380/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36380/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36380/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36808
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36808/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36808/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36808/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-36808/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37236
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37236/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37236/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37236/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37236/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37664
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37664/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37664/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37664/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-37664/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38092
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38092/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38092/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38092/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38092/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38520
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38520/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38520/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38520/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38520/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38948
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38948/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38948/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38948/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-38948/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39376
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39376/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39376/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39376/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39376/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39804
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39804/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39804/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39804/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39804/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40232
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40232/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40232/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40232/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40232/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40660
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40660/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40660/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40660/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-40660/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41088
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41088/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41088/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41088/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41088/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41516
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41516/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41516/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41516/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41516/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41944
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41944/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41944/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41944/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-41944/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42372
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42372/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42372/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42372/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42372/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
# Saving model checkpoint to /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42800
# Configuration saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42800/config.json
# Model weights saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42800/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42800/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-42800/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/drive/MyDrive/domain-helper//level-results-2/checkpoint-39376 (score: 0.9301574485264433).
# TrainOutput(global_step=42800, training_loss=0.030109012987569114, metrics={'train_runtime': 8925.5697, 'train_samples_per_second': 95.815, 'train_steps_per_second': 4.795, 'total_flos': 2.897945538528067e+16, 'train_loss': 0.030109012987569114, 'epoch': 100.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 475
#   Batch size = 20
#     <div>
#
#       <progress value='24' max='24' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [24/24 00:01]
#     </div>
# {'epoch': 100.0,
#  'eval_accuracy': 0.9305263157894736,
#  'eval_f1': 0.9301574485264433,
#  'eval_loss': 0.032992247492074966,
#  'eval_roc_auc': 0.9466084256705278,
#  'eval_runtime': 1.5706,
#  'eval_samples_per_second': 302.43,
#  'eval_steps_per_second': 15.281}

# %%
french_labels = {"http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-002": "école maternelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-008": "école élémentaire",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-016": "collège",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-065": "voie professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-066": "voie générale et technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-140": "adaptation scolaire et scolarisation des élèves handicapés",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-141": "collège professionnel",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-142": "lycée général et technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-163": "formation des personnels de l'éducation nationale",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-164": "formation professionnelle continue des adultes",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-165": "lycée professionnel",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-185": "licence professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-195": "section BTS",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-198": "section DUT",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-226": "voie CPGE",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-239": "11-15 ans",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-240": "15-18 ans",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-241": "3-6 ans",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-242": "6-11 ans",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-615": "cycles de l'enseignement scolaire (2016)",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-063": "formation continue des personnels de l'éducation nationale",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-136": "2de générale et technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-146": "1re générale",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-201": "terminale générale",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-211": "terminale technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-134": "1re ST2S",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-123": "1re générale et technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-083": "terminale STMG",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-047": "terminale STI2D",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-043": "terminale ST2S",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-044": "terminale STD2A",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-048": "terminale STL",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-641": "terminale STHR",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-650": "2de STHR",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-132": "1re STL",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-237": "1re technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-620": "cycle 3 (2016)",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-621": "cycle 4 (2016)",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-619": "cycle 2 (2016)",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-027": "2de professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-050": "terminale professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-127": "1re professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-223": "voie CAP",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-133": "1re STMG",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-129": "1re STD2A",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-131": "1re STI2D",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-088": "terminale générale et technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-617": "cycle 1 (2016)",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-640": "1re STHR",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-162": "enseignement supérieur en lycée",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-214": "voie BMA",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-221": "voie BT",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-222": "voie BTM",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-187": "diplôme de comptabilité et gestion",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-212": "terminale TMD",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-238": "1re TMD",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-023": "3e",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-618": "cycles de la scolarité obligatoire",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-004": "toute petite section",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-005": "petite section",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-006": "moyenne section",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-007": "grande section",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-003": "cycle 1",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-009": "cycle 2",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-010": "CP",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-011": "CE1",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-013": "CE2",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-014": "CM1",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-015": "CM2",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-012": "cycle 3",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-018": "6e",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-020": "5e",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-021": "4e",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-017": "cycle d'adaptation",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-019": "cycle central",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-022": "cycle d'orientation",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-608": "3e d'insertion",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-084": "classe de détermination",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-040": "terminale ES",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-041": "terminale L",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-042": "terminale S",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-085": "cycle terminal",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-233": "voie technologique",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-049": "terminale techno hôtellerie",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-089": "terminale pro domaine de la production",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-090": "terminale pro domaine des services",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-095": "BMA - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-096": "BMA - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-097": "BP - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-098": "BP - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-099": "BTM - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-100": "BTM - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-103": "CAP - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-104": "CAP - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-125": "1re pro domaine de la production",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-126": "1re pro domaine des services",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-138": "3e professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-139": "4e professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-213": "voie BEP",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-215": "voie BP",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-227": "voie FC",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-231": "voie MC",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-288": "FC post niveau IV",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-298": "FC post niveau V",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-230": "voie générale",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-135": "1re techno hôtellerie",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-094": "cycles de l'enseignement scolaire",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-101": "BTS - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-102": "BTS - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-109": "CPGE - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-110": "CPGE - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-111": "DUT - 1re année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-112": "DUT - 2e année",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-121": "tranches d'âge de l'enseignement scolaire",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-626": "Niveau éducatif détaillé (2015-)",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-122": "1re ES",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-124": "1re L",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-128": "1re S",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-150": "ASSEH - 1er degré",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-151": "ASSEH - 2d degré",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-153": "BT - première",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-154": "BT - terminale",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-234": "voies générale, technologique, professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-284": "formation professionnelle",
                 "http://data.education.fr/voc/scolomfr/concept/scolomfr-voc-022-num-616": "cycle unique pour l'école maternelle"}

# %%
texts = list(map(lambda entry: entry['text'], dataset["test"]))

for text  in texts:
  encoding = tokenizer(text, return_tensors="pt")
  encoding = {k: v.to(trainer.model.device) for k,v in encoding.items()}

  outputs = trainer.model(**encoding)
  logits = outputs.logits
  # apply sigmoid + threshold
  sigmoid = torch.nn.Sigmoid()
  probs = sigmoid(logits.squeeze().cpu())
  predictions = np.zeros(probs.shape)
  predictions[np.where(probs >= 0.5)] = 1
  # turn predicted id's into actual label names
  predicted_labels = [id2label[idx] for idx, label in enumerate(predictions) if label == 1.0]
  predicted_labels_with_scores = [french_labels[f'http://data.education.fr/voc/scolomfr/concept/{id2label[idx]}'] + '->' + str(round(probs[idx].item()*100,2))+'%' for idx, label in enumerate(predictions) if label == 1.0]
  print("***************")
  print (text)
  print(predicted_labels_with_scores)
  max = torch.argmax(probs).item()
  print('Maximum : ' + french_labels[f'http://data.education.fr/voc/scolomfr/concept/{id2label[max]}'])
# Out:
# ***************
# Sciences de la Vie& de la Terre- Cycle4-2017 - Manuel Numérique Enseignant - 3 ans-CNS
# ['5e->99.83%', '4e->99.94%', '3e->98.16%']
# Maximum : 4e
# ***************
# E.S.P.A.C.E. Physique Chimie 5è enseignant adoptant papier 5ans
# ['5e->98.67%']
# Maximum : 5e
# ***************
# Manuel numérique Droit Terminale STMG - Élève non adoptant manuel papier
# ['terminale STMG->94.86%']
# Maximum : terminale STMG
# ***************
# Activités d'économie - Enseignant Terminale STMG
# ['terminale STMG->96.24%']
# Maximum : terminale STMG
# ***************
# Odyssée Maths Terminale S enseignement spécifique éd. 2012 - Manuel interactif
# ['terminale générale->99.35%']
# Maximum : terminale générale
# ***************
# Etincelles - Lecture CP Éd. 2018 - Tika et Tao - La tour infernale - Album numérique enrichi 5
# ['CP->97.91%']
# Maximum : CP
# ***************
# Office 2016 - Pack Office 2016 - Outils collaboratifs et d'animation
# ['CAP - 1re année->54.35%', 'CAP - 2e année->54.88%']
# Maximum : CAP - 2e année
# ***************
# Ribambelle - Français CE2 Éd 2017 - Cahier lecture écriture numérique enrichi +livret lecture fluide
# ['CE2->97.0%']
# Maximum : CE2
# ***************
# Prévention Santé Environnement 3e DP - Manuel numérique - Licence élève - Ed.2011
# ['3e professionnelle->88.0%']
# Maximum : 3e professionnelle
# ***************
# Économie Tle STMG (2020) Manuel - LIB manuel numérique élève
# ['terminale ST2S->99.96%', 'terminale STD2A->99.76%', 'terminale STI2D->99.96%', 'terminale STL->99.87%', 'terminale techno hôtellerie->98.59%', 'terminale STMG->99.97%', 'terminale TMD->98.46%', 'terminale STHR->99.47%']
# Maximum : terminale STMG
# ***************
# ESPACE Physique-Chimie Tle 2020 Manuel num. enseignant adoptant papier via CNS
# ['terminale générale->99.14%', 'terminale ST2S->99.98%', 'terminale STD2A->99.88%', 'terminale STI2D->99.97%', 'terminale STL->99.86%', 'terminale techno hôtellerie->99.52%', 'terminale STMG->100.0%', 'terminale TMD->99.53%', 'terminale STHR->99.54%']
# Maximum : terminale STMG
# ***************
# Les Nouveaux Outils pour le Français CE2 (2016) - Manuel numérique enseignant
# ['CE2->97.01%']
# Maximum : CE2
# ***************
# Odysséo Sciences CM1 (2014) - Manuel numérique enseignant
# ['CM1->93.78%']
# Maximum : CM1
# ***************
# Prévention Santé Environnement (PSE) 2de Bac Pro (2021) - LIB manuel numérique enseignant
# ['2de professionnelle->91.47%']
# Maximum : 2de professionnelle
# ***************
# Les parcours pros de la PSE 1re, Tle - Bacs Pros Tertiaires et ASSP (2016) - Manuel numérique enseignant
# ['1re STD2A->99.84%', '1re STI2D->99.97%', '1re STL->99.88%', '1re STMG->99.99%', '1re ST2S->99.69%', '1re techno hôtellerie->99.39%', 'terminale générale->99.66%', 'terminale ST2S->99.82%', 'terminale STD2A->99.88%', 'terminale STI2D->99.96%', 'terminale STL->99.86%', 'terminale techno hôtellerie->99.47%', 'terminale STMG->99.96%', 'terminale TMD->99.45%', 'terminale pro domaine de la production->99.91%', 'terminale pro domaine des services->99.89%', '1re pro domaine de la production->99.62%', '1re pro domaine des services->99.64%', '1re TMD->99.33%', '1re générale->99.57%']
# Maximum : 1re STMG
# ***************
# Management des entreprises 2e année BTS Pochette (2015) - Manuel numérique enseignant
# ['BTS - 1re année->99.28%', 'BTS - 2e année->99.23%']
# Maximum : BTS - 1re année
# ***************
# Transmath 1re - 2019
# ['1re générale->99.0%']
# Maximum : 1re générale
# ***************
# Cahier de Physique-Chimie 3e Evaluation des compétences ed 2018 - Manuel numérique traditionnel (Lib Manuels) - Licence enseignant
# ['3e->98.83%']
# Maximum : 3e
# ***************
# Manuel numérique élève simple et personnalisable En Situation Management des organisations Terminale STMG Ed 2013
# ['terminale STMG->96.56%']
# Maximum : terminale STMG
# ***************
# Mathématiques 2de Bac Pro - Production - Manuel numérique enseignant - Éd 2020
# ['2de professionnelle->99.56%']
# Maximum : 2de professionnelle
# ***************
# Cap Maths CM2, éd. 2021, Manuel Nombres + Cahier de géom + Dico. Pack numérique enseignant
# ['CM2->96.58%']
# Maximum : CM2
# ***************
# Passerelles - Histoire-Géographie-EMC 2de Bac Pro - Éd. 2019 - Manuel numérique enseignant
# ['2de professionnelle->99.59%']
# Maximum : 2de professionnelle
# ***************
# Les nouveaux cahiers - Histoire-Géographie-EMC 2de Bac Pro - Éd. 2019 - Manuel numérique élève
# ['2de professionnelle->99.55%']
# Maximum : 2de professionnelle
# ***************
# Français Passeurs de textes 4e - 2016 - Manuel numérique élève - Abonnement 1 an
# ['4e->98.9%']
# Maximum : 4e
# ***************
# Manuel numérique Dossiers et études Économie Droit Seconde professionnelle Bac pro tertiaires - Enseignant adoptant
# ['2de professionnelle->99.61%']
# Maximum : 2de professionnelle
# ***************
# Connexions - Métiers de l'accueil, 1re-Tle Bac Pro, éd. 2020. Manuel numérique PREMIUM élève
# ['terminale pro domaine de la production->99.65%', 'terminale pro domaine des services->99.62%', '1re pro domaine de la production->99.84%', '1re pro domaine des services->99.86%']
# Maximum : 1re pro domaine des services
# ***************
# Parcours interactifs - Assurer le suivi administratif des activités 1re Bac Pro AGOrA- 2021 MN élève
# ['1re pro domaine de la production->98.42%', '1re pro domaine des services->98.31%']
# Maximum : 1re pro domaine de la production
# ***************
# Manuel numérique en ligne Économie - Gestion Seconde, Première et Terminale professionnelles Baccalauréats professionnels industriels - Élève adoptant manuel papier
# ['2de professionnelle->99.46%']
# Maximum : 2de professionnelle
# ***************
# Latitudes 3 niv.B1 - Manuel numérique premium élève
# ['2de générale et technologique->99.51%']
# Maximum : 2de générale et technologique
# ***************
# Mon cahier de Français 4e (2017) - LIB manuel numérique enseignant
# ['4e->98.91%']
# Maximum : 4e
# ***************
# Économie-Droit - Terminale professionnelle - Élève Tous Bac pro tertiaires
# ['terminale pro domaine de la production->98.77%', 'terminale pro domaine des services->98.77%']
# Maximum : terminale pro domaine de la production
# ***************
# Etincelles - Français CE1 Ed. 2019 - Livre de lectures - Manuel numérique élève
# ['CE1->96.51%']
# Maximum : CE1
# ***************
# Manuel numérique Distribution et utilisation de l'énergie Première et terminale professionnelles Bac pro ELEEC - Élève
# ['terminale pro domaine de la production->99.81%', 'terminale pro domaine des services->99.78%', '1re pro domaine de la production->99.78%', '1re pro domaine des services->99.81%']
# Maximum : 1re pro domaine des services
# ***************
# Version numérique enseignant Cahier du citoyen 5e - éd. 2019
# ['5e->98.82%']
# Maximum : 5e
# ***************
# Indice Mathématiques 1ère S 2015 élève
# ['1re générale->99.5%']
# Maximum : 1re générale
# ***************
# Be savvy! 2de Bac Pro - Manuel numérique - Licence élève - Ed.2009
# ['2de professionnelle->99.5%']
# Maximum : 2de professionnelle
# ***************
# Fantastisch! 1re année - Clé USB
# ['6e->97.49%', '5e->99.78%', '4e->82.5%']
# Maximum : 5e
# ***************
# Mathématiques 1ère Bac Pro groupements A et B - Manuel numérique enseignant -  Éd. 2021
# ['1re pro domaine de la production->98.53%', '1re pro domaine des services->98.43%']
# Maximum : 1re pro domaine de la production
# ***************
# Manuel numérique élève - Les Cahiers Istra Questionner le monde CE1 - Edition 2017
# ['CE1->96.04%']
# Maximum : CE1
# ***************
# Manuel numérique Histoire/Géographie 2nde compilation - Licence enseignant - Ed. 2019
# ['2de générale et technologique->99.68%']
# Maximum : 2de générale et technologique
# ***************
# Maths Term A-B Pro Ed 2011 - Manuel numérique - Licence élève
# ['terminale générale->99.11%']
# Maximum : terminale générale
# ***************
# Outils pour les Maths CM2 (2021) - Fiches d'entraînement - Manuel numérique enseignant
# ['CM2->95.09%']
# Maximum : CM2
# ***************
# Manuel numérique enseignant Fil à fil CM
# ['CM1->96.69%', 'CM2->99.5%']
# Maximum : CM2
# ***************
# Terre des Lettres Français 4ème 2017 - Manuel Numérique Enseignant -Lic. Longue - Adopt. - CNS
# ['4e->98.81%']
# Maximum : 4e
# ***************
# Connaitre et maitriser la langue 2de Bac Pro (2019) - Français - LIB manuel numérique élève
# ['2de professionnelle->99.48%']
# Maximum : 2de professionnelle
# ***************
# Maths Metamaths 1re ed.2019 - Manuel numérique traditionnel (Lib Manuels) - Licence élève
# ['1re générale->99.14%']
# Maximum : 1re générale
# ***************
# Mathématiques groupement C 1re Bac Pro - Manuel numérique
# ['1re STD2A->99.79%', '1re STI2D->99.97%', '1re STL->99.85%', '1re STMG->99.99%', '1re ST2S->99.72%', '1re techno hôtellerie->98.76%', 'terminale générale->94.94%', 'terminale ST2S->99.42%', 'terminale STD2A->99.58%', 'terminale STI2D->99.9%', 'terminale STL->99.56%', 'terminale techno hôtellerie->96.56%', 'terminale STMG->99.89%', 'terminale TMD->96.64%', 'terminale pro domaine de la production->98.9%', 'terminale pro domaine des services->98.77%', '1re pro domaine de la production->98.08%', '1re pro domaine des services->98.22%', '1re TMD->98.59%', '1re générale->97.91%']
# Maximum : 1re STMG
# ***************
# Bloc 2 - Animation et dynamisation de l'offre commerciale 1re et 2e années BTS MCO (2019) - Manuel numérique enseignant
# ['BTS - 1re année->99.2%', 'BTS - 2e année->99.16%']
# Maximum : BTS - 1re année
# ***************
# Continuité - Parcours auto-adaptatif collège - Éval. initiale 40 min - Accès valables jusqu'à la réouverture des établissements scolaires
# ['6e->99.29%', '5e->99.94%', '4e->99.35%', '3e->99.86%', '2de générale et technologique->96.32%']
# Maximum : 5e
# ***************
# Cahier d'activités Espagnol 4e ed 2017 - Manuel numérique traditionnel (Lib Manuels) - Licence enseignant
# ['4e->98.84%']
# Maximum : 4e
# ***************
# Maths tout terrain CE1 2020 Fichier numérique élève Licence 1 an 100% numérique
# ['CP->63.12%', 'CE1->97.78%']
# Maximum : CE1
# ***************
# Alouette Français CE1 2017 élève
# ['CE1->96.07%']
# Maximum : CE1
# ***************
# Prévention Santé Environnement (PSE) 1re, Tle Bac Pro (Ed. num. 2021) - FLEX manuel numérique granulaire élève
# ['1re STD2A->99.82%', '1re STI2D->99.97%', '1re STL->99.87%', '1re STMG->99.99%', '1re ST2S->99.68%', '1re techno hôtellerie->99.38%', 'terminale générale->99.68%', 'terminale ST2S->99.81%', 'terminale STD2A->99.88%', 'terminale STI2D->99.96%', 'terminale STL->99.86%', 'terminale techno hôtellerie->99.51%', 'terminale STMG->99.96%', 'terminale TMD->99.47%', 'terminale pro domaine de la production->99.91%', 'terminale pro domaine des services->99.89%', '1re pro domaine de la production->99.71%', '1re pro domaine des services->99.73%', '1re TMD->99.31%', '1re générale->99.57%']
# Maximum : 1re STMG
# ***************
# Manuel numérique Planète SVT 2nde - Licence enseignant - Ed. 2019
# ['2de générale et technologique->99.62%']
# Maximum : 2de générale et technologique
# ***************
# Français L'Oeil et la Plume 3e ed 2012 - Manuel numérique enseignant
# ['3e->98.9%']
# Maximum : 3e
# ***************
# Ribambelle CP Série violette Cahier d'activités 1 éd. 2014 - Manuel interactif
# ['CP->98.31%']
# Maximum : CP
# ***************
# Carnet de réussite FRANCAIS - CAP-Bac Pro - Éd. 2019 - Manuel numérique élève
# ['2de professionnelle->99.62%']
# Maximum : 2de professionnelle
# ***************
# Bloggers NEW 6e - Licence élève workbook numérique
# ['6e->98.9%']
# Maximum : 6e
# ***************
# Manuel numérique Maths Repères 1ère S - Licence enseignant - Edition 2011
# ['1re générale->99.37%']
# Maximum : 1re générale
# ***************
# Le Nouvel A portée de mots - Français CE2 - Manuel numérique simple enseignant - Ed. 2017
# ['CE2->96.78%']
# Maximum : CE2
# ***************
# Sciences de gestion et numérique - 1re STMG - coll. Réflexe
# ['1re STMG->95.45%']
# Maximum : 1re STMG
# ***************
# Français 2ème Bac Pro (Panoramas) Elève - 2017
# ['2de professionnelle->99.61%']
# Maximum : 2de professionnelle
# ***************
# Tremplin - GESTION FINANCE Tle STMG - Enseignement spécifique - Éd. 2020 - Numérique PREMIUM élève
# ['terminale STMG->95.79%']
# Maximum : terminale STMG
# ***************
# Anglais English Sparks 1re ed.2019 - Manuel numérique max Premium - Licence élève
# ['1re STD2A->99.93%', '1re STI2D->99.97%', '1re STL->99.92%', '1re STMG->100.0%', '1re ST2S->99.99%', '1re techno hôtellerie->99.29%', '1re TMD->99.24%', '1re STHR->99.31%', '1re générale->98.88%']
# Maximum : 1re STMG
# ***************
# Terre des Lettres Français 3ème 2017 - Manuel Numérique Enseignant -Lic. Longue - Adopt. - CNS
# ['3e->99.02%']
# Maximum : 3e
# ***************
# Les Dossiers Hachette Histoire Cycle 2 - Histoire des Arts - Manuel num simple enseignant - Ed. 2013
# ['CP->97.99%', 'CE1->97.02%']
# Maximum : CP
# ***************
# So English! - Anglais 3e Éd. 2017 - Manuel numérique enrichi élève
# ['3e->99.23%']
# Maximum : 3e
# ***************
# U4 Stéphane
# ['5e->98.99%']
# Maximum : 5e
# ***************
# Azione - cycle 4 -  2017 - Manuel Numérique Elève - 3 ans - CNS
# ['CM1->99.2%', 'CM2->99.1%', '6e->99.38%', '5e->99.96%', '4e->99.72%', '3e->98.89%']
# Maximum : 5e
# ***************
# Maths Metamaths 1re ed.2019 - Manuel numérique traditionnel (Lib Manuels) - Licence enseignant
# ['1re générale->99.12%']
# Maximum : 1re générale
# ***************
# En situation Gestion et Finance Terminale STMG - Manuel numérique élève - Éd. 2020
# ['terminale STMG->95.79%']
# Maximum : terminale STMG
# ***************
# Version numérique enseignant Cahier du citoyen Enseignement Moral et Civique (EMC) 5e (2015)
# ['5e->98.86%']
# Maximum : 5e
# ***************
# Manuel numérique Histoire Zachary 1re ES/L/S - Licence enseignant - Edition 2011
# ['1re générale->99.4%']
# Maximum : 1re générale
# ***************
# Passeurs de textes Français 1re - 2019 - Manuel numérique élève - non adoptant
# ['1re générale->99.34%']
# Maximum : 1re générale
# ***************
# Au bout des longues neiges
# ['5e->99.42%']
# Maximum : 5e
# ***************
# Histoire Géographie EMC Tle Bac Pro (2021) - Manuel - Banque de ressources élève
# ['1re STD2A->99.82%', '1re STI2D->99.97%', '1re STL->99.87%', '1re STMG->99.99%', '1re ST2S->99.67%', '1re techno hôtellerie->99.38%', 'terminale générale->99.67%', 'terminale ST2S->99.82%', 'terminale STD2A->99.88%', 'terminale STI2D->99.96%', 'terminale STL->99.87%', 'terminale techno hôtellerie->99.53%', 'terminale STMG->99.96%', 'terminale TMD->99.49%', 'terminale pro domaine de la production->99.91%', 'terminale pro domaine des services->99.89%', '1re pro domaine de la production->99.73%', '1re pro domaine des services->99.75%', '1re TMD->99.31%', '1re générale->99.56%']
# Maximum : 1re STMG
# ***************
# Espagnol Algo Mas 2e ed 2010 - Manuel numérique simple
# ['2de générale et technologique->99.64%']
# Maximum : 2de générale et technologique
# ***************
# Manuel numérique élève enrichi et personnalisable ¡Venga! Espagnol Term. séries technologiques Ed 2008
# ['terminale ST2S->96.8%', 'terminale STI2D->93.1%', 'terminale STL->57.95%', 'terminale STMG->99.82%']
# Maximum : terminale STMG
# ***************
# Maths Nouveau Prisme 5e ed 2010 - Manuel numérique enseignant
# ['5e->98.86%']
# Maximum : 5e
# ***************
# Community 1re - Pack numérique enseignant
# ['1re STD2A->99.91%', '1re STI2D->99.97%', '1re STL->99.91%', '1re STMG->100.0%', '1re ST2S->99.98%', '1re techno hôtellerie->99.04%', '1re TMD->98.98%', '1re STHR->99.13%', '1re générale->97.29%']
# Maximum : 1re STMG
# ***************
# Employé de vente spécialisé - Options A et B
# ['CAP - 1re année->91.64%', 'CAP - 2e année->91.32%']
# Maximum : CAP - 1re année
# ***************
# Accompagnement Numérique Personnalisé - Espagnol 3e - Abonnement 4 ans
# ['3e->99.23%']
# Maximum : 3e
# ***************
# Histoire Géographie EMC 6e ed.2021 - Manuel numérique max Premium - Licence enseignant
# ['6e->98.88%']
# Maximum : 6e
# ***************
# Au Rythme des maths CM1 2017 élève 5ans
# ['CM1->94.93%']
# Maximum : CM1
# ***************
# Parcours digital Fleurs d'encre français cycle 3 / 6e (2016) - Licence enseignant
# ['6e->99.03%']
# Maximum : 6e
# ***************
# Education Civique 6e ed 2009 - Manuel numérique élève
# ['6e->99.0%']
# Maximum : 6e
# ***************
# Les petits Magellan Cycle 3 éd. 2014 - Le Moyen Age - Manuel interactif
# ['CE2->99.1%', 'CM1->99.84%', 'CM2->98.41%']
# Maximum : CM1
# ***************
# Perspectives - DROIT-ECONOMIE Tle STMG - Éd. 2020 - Manuel numérique premium enseignant
# ['terminale STMG->95.02%']
# Maximum : terminale STMG
# ***************
# Économie-Droit - Terminale professionnelle - Enseignant Tous Bac pro tertiaires
# ['terminale pro domaine de la production->98.73%', 'terminale pro domaine des services->98.72%']
# Maximum : terminale pro domaine de la production
# ***************
# Education Civique 4e ed 2011 - Manuel numérique simple
# ['4e->98.85%']
# Maximum : 4e
# ***************
# Le livre du pâtissier (2016) - LIB manuel numérique élève
# ['CAP - 1re année->96.19%', 'CAP - 2e année->95.41%', 'BTS - 1re année->97.69%', 'BTS - 2e année->97.58%']
# Maximum : BTS - 1re année
# ***************
# Physique-Chimie 2de Bac Pro - Manuel numérique élève - Éd. 2019
# ['2de professionnelle->99.52%']
# Maximum : 2de professionnelle
# ***************
# Cahier connecté Anglais 4e ed 2017 - Offres pour la classe
# ['4e->98.79%']
# Maximum : 4e
# ***************
# Economie-Gestion 2e Bac Pro ASSP
# ['2de professionnelle->99.65%']
# Maximum : 2de professionnelle
# ***************
# Enseignement scientifique Tle (Ed. num. 2021) - LIB manuel numérique PREMIUM actualisé élève
# ['terminale générale->99.24%']
# Maximum : terminale générale
# ***************
# Taoki trie les déchets - Album Niveau 1 numérique enseignant - Edition 2021
# ['CP->94.37%']
# Maximum : CP
# ***************
# Passerelles - FRANCAIS - Tle Bac Pro - Ed. 2021 - Manuel numérique enseignant
# ['terminale pro domaine de la production->98.15%', 'terminale pro domaine des services->98.19%']
# Maximum : terminale pro domaine des services
# ***************
# Manuel interactif Histoire 1re L/ES/S
# ['1re générale->99.75%']
# Maximum : 1re générale
# ***************
# Sciences physiques et chimiques - Tle ST2S
# ['terminale ST2S->50.81%']
# Maximum : terminale ST2S
# ***************
# Enseignement Scientifique terminales - Manuel numérique élève premium - Ed. 2020
# ['terminale générale->99.8%', 'terminale ST2S->99.98%', 'terminale STD2A->99.89%', 'terminale STI2D->99.97%', 'terminale STL->99.86%', 'terminale techno hôtellerie->99.68%', 'terminale STMG->100.0%', 'terminale TMD->99.68%', 'terminale STHR->99.63%']
# Maximum : terminale STMG
# ***************
# Les Ateliers Hachette Histoire-Géographie CM1 - Manuel numérique enseignant - Ed 2010
# ['CM1->94.83%']
# Maximum : CM1
# ***************
# Manuel numérique J'apprends l'économie et le droit 2nde professionnelle Bac pro tertiaires - Élève non adoptant manuel papier
# ['2de professionnelle->99.59%']
# Maximum : 2de professionnelle
# ***************
# Transmath 3e - 2016 - Manuel numérique élève licence 1 an
# ['3e->98.93%']
# Maximum : 3e
# ***************
# Mathématiques 2de Bac Pro (Ed. num. 2021) - LIB manuel numérique élève
# ['2de professionnelle->99.61%']
# Maximum : 2de professionnelle
# ***************
# Mathématiques 1re, Tle - Groupement C (2016) - Manuel numérique élève
# ['1re STD2A->99.98%', '1re STI2D->100.0%', '1re STL->99.98%', '1re STMG->100.0%', '1re ST2S->99.95%', '1re techno hôtellerie->99.82%', 'terminale générale->97.77%', 'terminale ST2S->99.97%', 'terminale STD2A->99.99%', 'terminale STI2D->100.0%', 'terminale STL->99.98%', 'terminale techno hôtellerie->99.82%', 'terminale STMG->100.0%', 'terminale TMD->99.86%', 'terminale pro domaine de la production->76.79%', 'terminale pro domaine des services->79.8%', '1re pro domaine de la production->67.61%', '1re pro domaine des services->67.66%', '1re TMD->99.8%', '1re générale->97.44%']
# Maximum : terminale STMG
# ***************
# La conduite entretien de vente 2de Bac Pro - Manuel numérique élève simple - Ed. 2015
# ['2de professionnelle->99.56%']
# Maximum : 2de professionnelle
# ***************
# Give me five! - 4e - 2017 - Manuel numérique élève - Licence 1 an
# ['4e->98.91%']
# Maximum : 4e
# ***************
# Carnet de réussite MATHS - CAP-Bac Pro - Éd. 2019 - Manuel numérique élève
# ['2de professionnelle->99.71%']
# Maximum : 2de professionnelle
# ***************
# Économie-Droit 2de Bac Pro (2021) - LIB manuel numérique élève
# ['2de professionnelle->99.63%']
# Maximum : 2de professionnelle
# ***************
# Coccinelle Français CE1 éd. 2016 - Livre de Français + Cahiers 1 et 2- Manuel interactif enseignant
# ['CE1->96.5%']
# Maximum : CE1
# ***************
# Manuel numérique Les Couleurs du Français 4e Edition 2011 - Licence enseignant
# ['4e->98.89%']
# Maximum : 4e
# ***************
# Odysséo Questionner le monde CP-CE1 (2018) - Manuel numérique enseignant
# ['CP->96.46%', 'CE1->94.66%']
# Maximum : CP
# ***************
# Philosophie Tle série technologique ed 2020 - Manuel numérique max Premium - Licence élève
# ['terminale ST2S->99.97%', 'terminale STD2A->99.8%', 'terminale STI2D->99.96%', 'terminale STL->99.89%', 'terminale techno hôtellerie->98.68%', 'terminale STMG->99.98%', 'terminale TMD->98.57%', 'terminale STHR->99.53%']
# Maximum : terminale STMG
# ***************
# Manuel numérique enseignant simple et personnalisable Animer 1re Terminale BAC PRO Commerce Ed 2013
# ['terminale pro domaine de la production->99.72%', 'terminale pro domaine des services->99.69%', '1re pro domaine de la production->99.82%', '1re pro domaine des services->99.85%']
# Maximum : 1re pro domaine des services
# ***************
# Prévention Santé Environnement - CAP 1ère et 2ème années (MMS prof)
# ['CAP - 1re année->99.14%', 'CAP - 2e année->99.09%']
# Maximum : CAP - 1re année
# ***************
# Empreintes littéraires 1re Séries technologiques (2017)  - Manuel numérique enseignant
# ['1re STD2A->99.84%', '1re STI2D->99.95%', '1re STL->99.85%', '1re STMG->99.95%', '1re ST2S->99.98%', '1re techno hôtellerie->98.48%', '1re TMD->98.43%', '1re STHR->99.48%']
# Maximum : 1re ST2S
# ***************
# Myriade - Mathématiques 6e - 2016 - Manuel sur ViaScola - Abonnement 1 an
# ['6e->99.12%']
# Maximum : 6e
# ***************
# Cahier Histoire Géographie EMC 6e ed.2021 - Manuel numérique traditionnel (Lib Manuels) - Licence enseignant
# ['6e->98.9%']
# Maximum : 6e
# ***************
# Opération Maths CE1 Éd.2017 - Cahier numérique enrichi + Mémo
# ['CE1->96.11%']
# Maximum : CE1
# ***************
# Fokus Neu Allemand 1ère 2015 enseignant adoptant papier 5ans
# ['1re STMG->81.37%', '1re générale->99.4%']
# Maximum : 1re générale
# ***************
# Mon cahier de Français 3e (2017) - LIB manuel numérique élève
# ['3e->99.07%']
# Maximum : 3e
# ***************
# Cahier d’exercices - Français 4e- licence professeur et élève
# ['4e->98.78%']
# Maximum : 4e
# ***************
# SES 2e ed 2010 - Manuel numérique simple
# ['2de générale et technologique->99.72%']
# Maximum : 2de générale et technologique
# ***************
# Version numérique enseignant Cahier de français 5e - édition 2013
# ['5e->98.89%']
# Maximum : 5e
# ***************
# Économie 1re STMG : le programme en 12 situations (2016) Pochette - Manuel numérique enseignant
# ['1re STD2A->99.8%', '1re STI2D->99.95%', '1re STL->99.83%', '1re STMG->99.93%', '1re ST2S->99.97%', '1re techno hôtellerie->98.03%', '1re TMD->98.04%', '1re STHR->99.13%']
# Maximum : 1re ST2S
# ***************
# Le Robert - Manuel numérique enseignant de Philosophie ? Voie générale et voie technologique
# ['terminale générale->98.89%']
# Maximum : terminale générale
# ***************
# Prévention Santé Environnement (PSE) 2de Bac Pro (2017) - Manuel numérique élève
# ['2de générale et technologique->99.32%']
# Maximum : 2de générale et technologique
# ***************
# SVT 2de
# ['2de générale et technologique->99.7%']
# Maximum : 2de générale et technologique
# ***************
# Pásalo Bien Espagnol 2de, 1re, Tle Bac Pro (2020) - LIB manuel numérique enseignant
# ['2de professionnelle->99.62%']
# Maximum : 2de professionnelle
# ***************
# Bouquet Bi-Ecran Histoire Géo EMC 2016-Manuel Enseignant 3e - Adoptant -1 an
# ['CM1->99.15%', 'CM2->99.0%', '6e->99.31%', '5e->99.97%', '4e->99.73%', '3e->99.1%']
# Maximum : 5e
# ***************
# Magellan Questionner le temps et l'espace CE2 éd. 2016 - Manuel interactif élève
# ['CE2->96.8%']
# Maximum : CE2
# ***************
# QCm SVT -5e - CNS -  (Viascola) - Offre 6mois +2
# ['CM1->99.1%', 'CM2->98.96%', '6e->99.68%', '5e->99.97%', '4e->99.63%', '3e->98.81%']
# Maximum : 5e
# ***************
# Empreintes littéraires 2de (2015) - Manuel numérique élève
# ['2de générale et technologique->99.58%']
# Maximum : 2de générale et technologique
# ***************
# Manuel numérique Physique/Chimie 2nde - Licence enseignant - Ed. 2019
# ['2de générale et technologique->99.68%']
# Maximum : 2de générale et technologique
# ***************
# Cahier numérique enseignant enrichi cahier d'activités A mi me encanta cycle 4 3e - Ed. 2020
# ['3e->99.34%']
# Maximum : 3e
# ***************
# QCm SVT -4e - CNS -  (Viascola) - Offre 6mois +2
# ['CM1->99.37%', 'CM2->99.2%', '6e->99.56%', '5e->99.96%', '4e->99.74%', '3e->99.02%']
# Maximum : 5e
# ***************
# Les Chemins de la Pensée Philosophie Tle 2020 Manuel num. enseignant adoptant papier Licence 5ans vi
# ['terminale générale->99.72%', 'terminale ST2S->99.98%', 'terminale STD2A->99.91%', 'terminale STI2D->99.97%', 'terminale STL->99.89%', 'terminale techno hôtellerie->99.72%', 'terminale STMG->100.0%', 'terminale TMD->99.73%', 'terminale STHR->99.7%']
# Maximum : terminale STMG
# ***************
# Indice Maths Tles techno tronc commun 2020 Manuel num. élève Licence 5ans 100% numérique
# ['terminale générale->99.15%', 'terminale ST2S->99.99%', 'terminale STD2A->99.92%', 'terminale STI2D->99.98%', 'terminale STL->99.92%', 'terminale techno hôtellerie->99.75%', 'terminale STMG->100.0%', 'terminale TMD->99.76%', 'terminale STHR->99.75%']
# Maximum : terminale STMG
# ***************
# Nuevas Voces 2de - Manuel numérique premium enseignant
# ['2de générale et technologique->99.54%']
# Maximum : 2de générale et technologique
# ***************
# Chercheurs en herbe Sciences et Technologie CM Manuel num. enseignant adopt Pap Licence 5ans via CNS
# ['CP->98.86%', 'CE1->98.58%', 'CE2->99.13%', 'CM1->99.57%', 'CM2->97.05%', '6e->92.97%']
# Maximum : CM1
# ***************
# Histoire Géographie 6e ed 2009 - Manuel numérique enseignant
# ['6e->98.9%']
# Maximum : 6e
# ***************
# Les Chemins de la Pensée Philosophie Tle 2020 Manuel numérique élève Licence 5ans 100% numérique
# ['terminale générale->99.53%', 'terminale ST2S->99.99%', 'terminale STD2A->99.92%', 'terminale STI2D->99.98%', 'terminale STL->99.91%', 'terminale techno hôtellerie->99.75%', 'terminale STMG->100.0%', 'terminale TMD->99.75%', 'terminale STHR->99.76%']
# Maximum : terminale STMG
# ***************
# Match Point Anglais 2de, 1re, Tle Bac Pro (Ed. num. 2021) - LIB manuel numérique élève
# ['2de professionnelle->99.61%']
# Maximum : 2de professionnelle
# ***************
# Outils pour les Maths CE2 (2021) - Les Maths par période - Fichier - Manuel numérique enseignant
# ['CE2->97.08%']
# Maximum : CE2
# ***************
# Histoire Géographie EMC 1re, Tle Bac Pro (2021) - FLEX manuel numérique granulaire élève
# ['1re STD2A->99.82%', '1re STI2D->99.97%', '1re STL->99.87%', '1re STMG->99.99%', '1re ST2S->99.67%', '1re techno hôtellerie->99.36%', 'terminale générale->99.65%', 'terminale ST2S->99.82%', 'terminale STD2A->99.88%', 'terminale STI2D->99.96%', 'terminale STL->99.87%', 'terminale techno hôtellerie->99.52%', 'terminale STMG->99.96%', 'terminale TMD->99.48%', 'terminale pro domaine de la production->99.9%', 'terminale pro domaine des services->99.88%', '1re pro domaine de la production->99.71%', '1re pro domaine des services->99.73%', '1re TMD->99.28%', '1re générale->99.52%']
# Maximum : 1re STMG
# ***************
# Bloc 2 - Animation et dynamisation de l'offre commerciale 1re et 2e années BTS MCO (2019) - Manuel numérique élève
# ['BTS - 1re année->99.2%', 'BTS - 2e année->99.16%']
# Maximum : BTS - 1re année
# ***************
# Ribambelle CE2 Éd. 2017 - Nouvelles d'aujourd'hui - Album numérique enrichi
# ['CE2->96.4%']
# Maximum : CE2
# ***************
# Chut... Je lis ! Méthode de lecture CP - Manuel numérique simple Tome 1 enseignant - Ed. 2016
# ['CP->97.7%']
# Maximum : CP
# ***************
# Ahdaf A2 - Manuel numérique premium unique
# ['6e->97.87%', '5e->99.87%', '4e->99.15%', '3e->99.84%', '2de générale et technologique->98.85%']
# Maximum : 5e
# ***************
# Transmath - Les QCM - 5ème - 2017 - Cahier - 100% Numérique - Viascola
# ['5e->98.73%']
# Maximum : 5e
# ***************
# CAP Cuisine - enseignant - CAP CUISINE - enseignant
# ['CAP - 1re année->99.22%', 'CAP - 2e année->99.17%']
# Maximum : CAP - 1re année
# ***************
# Manuel numérique Sciences Economiques et Sociales T ES - Licence enseignant - Edition 2012
# ['terminale générale->98.17%']
# Maximum : terminale générale
# ***************
# Plateforme d'entrainement Mathématiques Barbazo 2nde  - Ed. 2019
# ['2de générale et technologique->99.51%']
# Maximum : 2de générale et technologique
# ***************
# Empreintes littéraires Français 1re (2021) - Cahier consommable - LIB manuel numérique enseignant
# ['1re STD2A->99.94%', '1re STI2D->99.98%', '1re STL->99.94%', '1re STMG->100.0%', '1re ST2S->99.99%', '1re techno hôtellerie->99.45%', '1re TMD->99.4%', '1re STHR->99.6%', '1re générale->94.07%']
# Maximum : 1re STMG
# ***************
# Manuel numérique Déclic maths Tle ES/L - Licence enrichie élève - éd. 2016
# ['terminale générale->99.34%']
# Maximum : terminale générale
# ***************
# Cahier Grevisse 3e (2021) - LIB manuel numérique enseignant
# ['3e->98.97%']
# Maximum : 3e
# ***************
# Manuel numérique New Spring 4e - Anglais - Licence enseignant - Edition 2008
# ['4e->98.84%']
# Maximum : 4e
# ***************
# Accompagnement Numérique Personnalisé - Mathématiques 5e - Abonnement 1 an
# ['5e->98.89%']
# Maximum : 5e
# ***************
# Indice 1re L/ES - Mathématiques - 2011 - Manuel numérique élève
# ['1re générale->99.04%']
# Maximum : 1re générale
# ***************
# Sciences de gestion et numérique SDGN 1re STMG Manuel (2021) - LIB manuel numérique enseignant
# ['1re STD2A->99.8%', '1re STI2D->99.95%', '1re STL->99.83%', '1re STMG->99.94%', '1re ST2S->99.97%', '1re techno hôtellerie->97.99%', '1re TMD->97.99%', '1re STHR->99.2%']
# Maximum : 1re ST2S
# ***************
# Wanderlust Allemand 1re 2019 Manuel num. enseignant adoptant papier Licence 5ans via CNS
# ['1re générale->99.4%']
# Maximum : 1re générale
# ***************
# Manuel numérique Littérature et Société 2de - Licence enseignant - Edition 2013
# ['2de générale et technologique->99.63%']
# Maximum : 2de générale et technologique
# ***************
# Espagnol En contacto 1re ed.2019 - Manuel numérique traditionnel (Lib Manuels) - Licence enseignant
# ['1re STD2A->99.92%', '1re STI2D->99.97%', '1re STL->99.92%', '1re STMG->100.0%', '1re ST2S->99.98%', '1re techno hôtellerie->99.16%', '1re TMD->99.11%', '1re STHR->99.14%', '1re générale->98.61%']
# Maximum : 1re STMG
# ***************
# Petite Alouette CP 2021 licence élève 100% numérique
# ['CP->99.52%']
# Maximum : CP
# ***************
# Indice Maths 2de 2019 enseignant adoptant papier
# ['2de générale et technologique->99.58%']
# Maximum : 2de générale et technologique
# ***************
# Histoire 2de (2015) - Manuel numérique élève
# ['2de générale et technologique->99.47%']
# Maximum : 2de générale et technologique
# ***************
# BAC PRO CSR 2nde - enseignant - BAC PRO CSR 2nde - enseignant
# ['2de professionnelle->99.58%']
# Maximum : 2de professionnelle
# ***************
# En situation Droit Tle STMG - Manuel interactif enseignant - Éd. 2018
# ['terminale STMG->94.81%']
# Maximum : terminale STMG
# ***************
# SES 1re (Ed. num. 2021) - Banque de ressources élève
# ['1re générale->99.35%']
# Maximum : 1re générale
# ***************
# Au Rythme des maths CM1 2017 Manuel num. enseignant adoptant papier Licence 1an via CNS
# ['CP->98.67%', 'CE1->98.1%', 'CE2->98.38%', 'CM1->99.68%', 'CM2->97.83%', '6e->97.35%']
# Maximum : CM1
# ***************
# Maths Metamaths 2de ed.2019 - Manuel numérique max Premium - Licence élève
# ['2de générale et technologique->99.52%']
# Maximum : 2de générale et technologique
# ***************
# Histoire-Géographie EMC - 3e Prépa-Métiers
# ['3e professionnelle->92.26%']
# Maximum : 3e professionnelle
# ***************
# Manuel numérique simple et personnalisable Première professionnelle Baccalauréat professionnel Métiers du commerce et de la vente Option B : Prospection clientèle et valorisation de l'offre commerciale - Élève - Éd. 2020
# ['1re pro domaine de la production->98.48%', '1re pro domaine des services->98.37%']
# Maximum : 1re pro domaine de la production
# ***************
# Manuel numérique élève simple et personnalisable Activités professionnelles Gestion administrative interne : les informations et les modes de travail 2de BAC PRO Gestion-Administration Ed 2012
# ['2de professionnelle->99.57%']
# Maximum : 2de professionnelle
# ***************
# Odyssée Mathématiques 1res ES/L éd. 2011 - Manuel interactif
# ['1re générale->99.49%']
# Maximum : 1re générale
# ***************
# Français 5e - 4e - 3e (cycle 4) - Livre du professeur Version numérique
# ['5e->99.88%', '4e->99.81%', '3e->99.73%']
# Maximum : 5e
# ***************
# Physique Chimie- Cycle4-2017 - Manuel Numérique Enseignant - 3 ans - CNS
# ['CM1->98.16%', 'CM2->98.26%', '6e->97.59%', '5e->99.97%', '4e->99.77%', '3e->98.86%']
# Maximum : 5e
# ***************
# Ribambelle CE1 série Jaune éd. 2016 - Cahier d'activités 1 - Manuel interactif
# ['CE1->95.89%']
# Maximum : CE1
# ***************
# Processus 7 -  BTS CG 1re et 2e années
# ['BTS - 1re année->99.21%', 'BTS - 2e année->99.16%']
# Maximum : BTS - 1re année
# ***************
# A8 - Communication globale BTS AG de PME-PMI 1re année Pochette (2015) - Manuel numérique enseignant
# ['BTS - 1re année->99.24%', 'BTS - 2e année->99.2%']
# Maximum : BTS - 1re année
# ***************
# Des cours d'anglais innovants
# ['6e->97.48%', '5e->93.64%', '4e->97.75%', '3e->99.94%', '2de générale et technologique->90.73%', '3e professionnelle->87.16%', '2de professionnelle->98.56%', 'BMA - 1re année->76.6%', 'BMA - 2e année->76.44%', 'BP - 1re année->93.91%', 'BP - 2e année->94.2%', 'CAP - 1re année->99.9%', 'CAP - 2e année->99.9%']
# Maximum : 3e
# ***************
# Economie Tle STMG
# ['terminale STMG->95.55%']
# Maximum : terminale STMG
# ***************
# Les Dossiers Hachette Mon corps, ma santé Cycle 2 - Manuel numérique élève - Ed 2011
# ['CP->99.1%', 'CE1->93.45%']
# Maximum : CP
# ***************
# Informatique - 2de/1re/Tle Bacs Pro tertiaires
# ['2de professionnelle->99.67%']
# Maximum : 2de professionnelle
# ***************
# Archimaths CP (2016) - Manuel numérique élève
# ['CP->97.77%']
# Maximum : CP
# ***************
# Physique-Chimie 1re ed.2019 - Manuel numérique max Premium - Licence élève
# ['1re générale->99.07%']
# Maximum : 1re générale
# ***************
# Français Lycée bac pro 2de/1re/Tle - Passeurs de textes - Manuel de l'élève
# ['2de professionnelle->99.55%']
# Maximum : 2de professionnelle
# ***************
# 3ème Prépa-métiers - SVT - Corrections - Enseignant
# ['3e professionnelle->91.51%']
# Maximum : 3e professionnelle
# ***************
# Ressources plus - ECONOMIE-GESTION 2de BAC PRO - Éd. 2019 - Manuel numérique enseignant
# ['2de professionnelle->99.59%']
# Maximum : 2de professionnelle
# ***************
# Together 6e - Manuel numérique enrichi élève
# ['6e->99.08%']
# Maximum : 6e
# ***************
# Les Docs Ribambelle Cycle 2 - Les fourmis - Manuel numérique
# ['CP->98.56%', 'CE1->96.18%']
# Maximum : CP
# ***************
# Outils pour les Maths CE1 (2021) - Les Maths par période - Mémo - Manuel numérique enseignant
# ['CE1->96.04%']
# Maximum : CE1
# ***************
# Nutrition Alimentation 2de, 1re, Tle Bac Pro ASSP (2018) - LIB manuel numérique enseignant
# ['2de professionnelle->99.62%']
# Maximum : 2de professionnelle
# ***************
# Economie Droit 2de Bac Pro - Manuel numérique - Licence enseignant - Ed.2010
# ['1re pro domaine de la production->59.81%', '1re pro domaine des services->63.74%']
# Maximum : 1re pro domaine des services
# ***************
# Anglais New on target 2e ed 2010 - Manuel numérique - Offres pour la classe
# ['2de générale et technologique->99.66%']
# Maximum : 2de générale et technologique
# ***************
# Ribambelle CP Série violette éd. 2014 - La princesse de pierre - Manuel interactif
# ['CP->98.2%']
# Maximum : CP
# ***************
# Manuel numérique Gestion et finance Terminale STMG - Élève non adoptant manuel papier
# ['terminale STMG->95.85%']
# Maximum : terminale STMG
# ***************
# Grammaire du collège - Français 6e/cycle 4 Éd 2019 - Manuel numérique
# ['6e->61.2%', '5e->97.46%', '3e->81.44%']
# Maximum : 5e
# ***************
# Le Nouvel A portée de maths CE1 - Manuel numérique simple enseignant - Ed. 2018
# ['CE1->96.18%']
# Maximum : CE1
# ***************
# Connaissance du véhicule 1re, Tle Bac Pro (2018) - LIB manuel numérique enseignant
# ['1re STD2A->99.83%', '1re STI2D->99.97%', '1re STL->99.87%', '1re STMG->99.99%', '1re ST2S->99.68%', '1re techno hôtellerie->99.38%', 'terminale générale->99.66%', 'terminale ST2S->99.82%', 'terminale STD2A->99.89%', 'terminale STI2D->99.96%', 'terminale STL->99.87%', 'terminale techno hôtellerie->99.52%', 'terminale STMG->99.96%', 'terminale TMD->99.49%', 'terminale pro domaine de la production->99.9%', 'terminale pro domaine des services->99.88%', '1re pro domaine de la production->99.7%', '1re pro domaine des services->99.72%', '1re TMD->99.31%', '1re générale->99.54%']
# Maximum : 1re STMG
# ***************
# Cahier numérique de français cycle 4 / 3e - Licence élève - Ed. 2018
# ['3e->99.05%']
# Maximum : 3e
# ***************
# Gute Fahrt! 1re année - 2009  - Manuel numérique élève
# ['CM1->98.32%', 'CM2->97.2%', '6e->99.94%', '5e->99.97%', '4e->99.75%', '3e->98.79%']
# Maximum : 5e
# ***************
# Ribambelle CP Série violette éd. 2014 - Aventure à la piscine - Manuel interactif
# ['CP->98.34%']
# Maximum : CP
# ***************
# Les Nouveaux Outils pour le Français CE2 (2018) - Fichier - Manuel numérique enseignant
# ['CE2->97.06%']
# Maximum : CE2
# ***************
# Parés au décodage CP - Méthode de lecture - Fichier 2 numérique enseignant - Ed. 2020
# ['CP->97.91%']
# Maximum : CP
# ***************
# Manuel numérique enrichi et personnalisable Les illustrés en scénarios Tome 4 - Pôles 1, 2 et 3 - Première professionnelle Baccalauréat professionnel Gestion - Administration - Enseignant
# ['1re pro domaine de la production->98.11%', '1re pro domaine des services->97.96%']
# Maximum : 1re pro domaine de la production
# ***************
# Histoire Géographie EMC CAP (2021) - LIB manuel numérique élève
# ['CAP - 1re année->98.91%', 'CAP - 2e année->98.84%']
# Maximum : CAP - 1re année
# ***************
# Taoki et compagnie CP - Taoki jardine - Album 1 numérique enseignant - Edition 2020
# ['CP->98.09%']
# Maximum : CP
# ***************
# Cahier connecté SVT 4e ed 2017 - Offres pour la classe
# ['4e->98.77%']
# Maximum : 4e
# ***************
# Hyperbole  2de - 2014 - Manuel numérique élève
# ['2de générale et technologique->99.61%']
# Maximum : 2de générale et technologique
# ***************
# Histoire Géographie EMC 2de Bac Pro ed.2021 - Manuel numérique traditionnel (Lib Manuels) - Licence enseignant
# ['2de professionnelle->99.59%']
# Maximum : 2de professionnelle
# ***************
# Hist-Géo-Histoire des Arts Odyssée CM1 ed 2011 - Manuel numérique élève
# ['CM1->94.2%']
# Maximum : CM1
# ***************
# Manuel numérique Électrotechnique : Lois fondamentales et Mesurages Seconde, Première et Terminale professionnelles Baccalauréat professionnel MELEC - Élève
# ['2de professionnelle->99.41%']
# Maximum : 2de professionnelle
# ***************
# Les Nouveaux Outils pour le Français CE2 (2013) - Manuel numérique enseignant
# ['CE2->96.92%']
# Maximum : CE2
# ***************
# Cup of tea CE2 - Manuel numérique enrichi élève
# ['CE2->96.6%']
# Maximum : CE2
# ***************
# QCM Physique Chimie -3e - CNS -(Viascola) - Offre 6 mois+2
# ['CM1->99.2%', 'CM2->98.97%', '6e->99.67%', '5e->99.97%', '4e->99.71%', '3e->99.27%']
# Maximum : 5e
# ***************
# Français Passeurs de textes 5e - 2016 - Manuel numérique enseignant - Offert pour l'achat de versions élèves
# ['5e->98.94%']
# Maximum : 5e
# ***************
# Histoire géographie 1re technologique (Ed. num. 2021) - LIB Banque de ressources enseignant
# ['1re STD2A->99.79%', '1re STI2D->99.95%', '1re STL->99.82%', '1re STMG->99.93%', '1re ST2S->99.97%', '1re techno hôtellerie->97.88%', '1re TMD->97.81%', '1re STHR->99.3%']
# Maximum : 1re ST2S
# ***************
# La Cuisine Expliquée - La Cuisine Expliquée - élève
# ['BP - 1re année->90.83%', 'BP - 2e année->91.02%', 'CAP - 1re année->99.95%', 'CAP - 2e année->99.94%', 'BTS - 1re année->99.87%', 'BTS - 2e année->99.85%']
# Maximum : CAP - 1re année
# ***************
# Français Méthodes et techniques - Elève - Classes des lycées - 2016
# ['1re STI2D->79.53%', '1re STMG->57.52%', '1re ST2S->92.63%']
# Maximum : 1re ST2S
# ***************
# Cahier connecté EMC collège ed 2016 - Offres pour la classe
# ['6e->89.63%', '5e->99.95%', '4e->99.01%', '3e->99.73%']
# Maximum : 5e
# ***************
# TRANSPORT TOME 2 - Première et Terminale Enseignant Bac Pro Transport
# ['terminale pro domaine de la production->99.8%', 'terminale pro domaine des services->99.78%', '1re pro domaine de la production->99.79%', '1re pro domaine des services->99.82%']
# Maximum : 1re pro domaine des services
# ***************
# Français Terminale Bac Pro - Manuel numérique - Licence élève - Ed.2011
# ['terminale pro domaine de la production->98.6%', 'terminale pro domaine des services->98.59%']
# Maximum : terminale pro domaine de la production
# ***************
# Prévention Santé Environnement 1re-Terminale Bac pro - Manuel numérique élève simple - Ed. 2014
# ['terminale pro domaine de la production->99.67%', 'terminale pro domaine des services->99.63%', '1re pro domaine de la production->99.77%', '1re pro domaine des services->99.8%']
# Maximum : 1re pro domaine des services
# ***************
# Manuel numérique élève simple et personnalisable Principes fondamentaux de l'économie et de la gestion 2de Ed 2014
# ['2de générale et technologique->99.53%']
# Maximum : 2de générale et technologique
# ***************
# Prévention Santé Environnement (PSE) 2de Bac Pro (2021) - LIB manuel numérique élève
# ['2de professionnelle->95.54%']
# Maximum : 2de professionnelle
# ***************
# Au Rythme des maths CM1 2020 Manuel numérique élève Licence 1an 100% numérique
# ['CM1->92.35%']
# Maximum : CM1
# ***************
# Mathématiques terminale STL spécialité Biotechnologies Nouveau programme
# ['terminale STMG->81.46%']
# Maximum : terminale STMG
# ***************
# Techniques professionnelles et techno associée - 1ère-Term BPro ASSP À Domicile élève - 2012
# ['terminale pro domaine de la production->99.76%', 'terminale pro domaine des services->99.74%', '1re pro domaine de la production->99.73%', '1re pro domaine des services->99.77%']
# Maximum : 1re pro domaine des services
# ***************
# Sciences de gestion et numérique 1re STMG Pochette (2021) - LIB manuel numérique élève
# ['1re STD2A->99.77%', '1re STI2D->99.94%', '1re STL->99.8%', '1re STMG->99.93%', '1re ST2S->99.97%', '1re techno hôtellerie->97.79%', '1re TMD->97.78%', '1re STHR->99.16%']
# Maximum : 1re ST2S
# ***************
# Les Nouveaux Outils pour le Français CM1 (2013) - Manuel numérique élève
# ['CM1->93.41%']
# Maximum : CM1
# ***************
# Enjeux et Repères Droit Tle STMG - Manuel numérique enseignant - Éd. 2018
# ['terminale STMG->95.5%']
# Maximum : terminale STMG
# ***************
# Histoire Cycle 3 Le Moyen Age Tout en doc ed 2013     - Manuel numérique enseignant
# ['CE2->98.05%', 'CM1->99.87%', 'CM2->98.5%']
# Maximum : CM1
# ***************
# Lecture CP - Collection Pilotis - Fichier de lecture compréhension numérique élève - Ed. 2013
# ['CP->97.17%']
# Maximum : CP
# ***************
# Manuel numérique Maths Repères Seconde - Licence élève - ed. 2010
# ['2de générale et technologique->99.54%']
# Maximum : 2de générale et technologique
# ***************
# Bled CM1-CM2 - Manuel numérique simple version enseignant - Edition 2017
# ['CM1->96.22%', 'CM2->99.74%']
# Maximum : CM2
# ***************
# Buena Onda Espagnol LV2 3e 2017 Manuel numérique élève Licence 5ans 100% numérique
# ['3e->99.26%']
# Maximum : 3e
# ***************
# Cap Maths CP éd. 2016 Fichier d'entrainement + Cahier de géométrie+ Dico Maths. Manuel numérique
# ['CP->98.39%']
# Maximum : CP
# ***************
# En situation Management des organisations Terminale STMG - Manuel numérique élève simple - Éd. 2016
# ['terminale STMG->95.74%']
# Maximum : terminale STMG
# ***************
# Taoki et compagnie CP - Le Monde de Taoki - ePub enseignant Album niveau 3 - Ed 2019
# ['CP->98.53%']
# Maximum : CP
# ***************
# Histoire Terminale 2020- licence professeur et élève
# ['terminale générale->99.74%', 'terminale ST2S->99.98%', 'terminale STD2A->99.9%', 'terminale STI2D->99.97%', 'terminale STL->99.88%', 'terminale techno hôtellerie->99.72%', 'terminale STMG->100.0%', 'terminale TMD->99.72%', 'terminale STHR->99.69%']
# Maximum : terminale STMG
# ***************
# Les Fleurs Du Mal / Coll. Classiques et Cie Lycée
# ['2de générale et technologique->99.55%']
# Maximum : 2de générale et technologique
# ***************
# Les Nouveaux Cahiers - Histoire-Géographie EMC 1re Bac Pro
# ['1re pro domaine de la production->98.39%', '1re pro domaine des services->98.28%']
# Maximum : 1re pro domaine de la production
# ***************
# Histoire-Géographie CM1 - Collection Citadelle - Livre élève - Ed. 2016
# ['CM1->94.55%']
# Maximum : CM1
# ***************
# Modulo - Mathématiques 1re Bac Pro - Groupements A et B - éd. 2020. Manuel numérique PREMIUM élève
# ['1re pro domaine de la production->98.47%', '1re pro domaine des services->98.38%']
# Maximum : 1re pro domaine de la production
# ***************
# Cybersécurité des services informatiques 1re année BTS Services Informatiques aux Organisations (SIO) (2020) - Manuel numérique enseignant
# ['BTS - 1re année->99.23%', 'BTS - 2e année->99.18%']
# Maximum : BTS - 1re année
# ***************
# Math'X 1re ES-L - Manuel numérique premium enseignant
# ['1re générale->99.46%']
# Maximum : 1re générale
# ***************
# Outils pour le Français CE1 (2019) - Manuel numérique enseignant
# ['CE1->96.19%']
# Maximum : CE1
# ***************
# Manuel numérique élève simple et personnalisable En Situation Droit Terminale STMG Ed 2013
# ['terminale STMG->95.7%']
# Maximum : terminale STMG
# ***************
# Français L'Oeil et la Plume 6e ed 2009 - Manuel numérique simple
# ['6e->99.01%']
# Maximum : 6e
# ***************
# Mercatique ens. spécifique Tle STMG (2020) Manuel - LIB manuel numérique enseignant
# ['terminale ST2S->99.96%', 'terminale STD2A->99.75%', 'terminale STI2D->99.95%', 'terminale STL->99.86%', 'terminale techno hôtellerie->98.47%', 'terminale STMG->99.98%', 'terminale TMD->98.33%', 'terminale STHR->99.48%']
# Maximum : terminale STMG
# ***************
# HIGH SPOT Tome unique 2de/1re/Tle Bac Pro - Éd. 2017 - Manuel numérique enrichi
# ['2de professionnelle->99.64%']
# Maximum : 2de professionnelle
# ***************
# Manuel numérique en ligne Installation électrique dans les bâtiments résidentiels Seconde professionnelle Baccalauréat professionnel MELEC - Élève adoptant manuel papier
# ['2de professionnelle->99.57%']
# Maximum : 2de professionnelle
# ***************
# Regaud Vento Physique Chimie 4è enseignant adoptant papier 5ans
# ['5e->99.68%', '4e->99.92%', '3e->99.57%']
# Maximum : 4e
# ***************
# Histoire-Géographie Terminales compilation - Manuel numérique élève premium - Ed. 2020
# ['terminale générale->98.73%', 'terminale ST2S->99.98%', 'terminale STD2A->99.88%', 'terminale STI2D->99.97%', 'terminale STL->99.87%', 'terminale techno hôtellerie->99.41%', 'terminale STMG->100.0%', 'terminale TMD->99.43%', 'terminale STHR->99.22%']
# Maximum : terminale STMG
# ***************
# Bled CE2 - Manuel numérique élève - Edition 2021
# ['CE2->96.56%']
# Maximum : CE2
# ***************
# Histoire Géographie 1re ES-L (2015) - Manuel numérique élève
# ['1re générale->99.41%']
# Maximum : 1re générale
# ***************
# Passeurs de textes - Le Robert WebLettres - 2019 - Français 2de - manuel numérique élève abonnement 5 ans Adoptant on-line seul
# ['2de générale et technologique->99.59%']
# Maximum : 2de générale et technologique
# ***************
# Outils pour les maths CM2 (2011) - Manuel numérique enseignant
# ['CM2->94.38%']
# Maximum : CM2
# ***************
# Histoire, Géographie, Éducation civique Lycée 2de/1re/Tle bac pro - Passeurs de mondes
# ['2de professionnelle->99.63%']
# Maximum : 2de professionnelle
# ***************
# Manuel interactif standard Etincelles CE1 Livre de lectures
# ['CE1->95.54%']
# Maximum : CE1
# ***************
# Physique Chimie 1re STI2D (2019) - LIB manuel numérique élève
# ['1re STD2A->99.76%', '1re STI2D->99.95%', '1re STL->99.81%', '1re STMG->99.9%', '1re ST2S->99.97%', '1re techno hôtellerie->97.46%', '1re TMD->97.41%', '1re STHR->99.1%']
# Maximum : 1re ST2S
# ***************
# ...
# Maximum : 1re ST2S
# ***************
# Les Trois Mousquetaires
# ['5e->96.4%', '3e->55.47%']
# Maximum : 5e
# ***************
# Mathématiques - Tle STMG
# ['terminale STMG->95.91%']
# Maximum : terminale STMG
# ***************
# Outils pour les Maths CE1 (2019) - Manuel numérique enseignant
# ['CE1->95.91%']
# Maximum : CE1
# ***************
# Manuel interactif standard Histoire-Géographie 6e
# ['6e->98.85%']
# Maximum : 6e
# ***************
# SCIENCES ET TECHNIQUES SANITAIRES ET SOCIALES 1re ST2S Éd. 2019 -Manuel numérique enseignant
# ['1re ST2S->63.67%']
# Maximum : 1re ST2S
# ***************
# CLEO CM2 Manuel de l'élève + Guide pédagogique - numérique enseignant - CNS adoptant (5 ans - gratuit)
# ['CP->95.64%', 'CE1->89.77%', 'CE2->92.53%', 'CM1->99.81%', 'CM2->99.4%', '6e->99.53%']
# Maximum : CM1
# ***************
# Technologie de service - 1re/Tle Bac Pro CSR
# ['terminale pro domaine de la production->99.84%', 'terminale pro domaine des services->99.82%', '1re pro domaine de la production->99.7%', '1re pro domaine des services->99.74%']
# Maximum : terminale pro domaine de la production
# ***************
# Manuel d'Histoire Franco-Allemand - Tome 2 - 2006 - Version simple - Licence élève 1 an
# ['terminale générale->98.42%']
# Maximum : terminale générale
# ***************
# Pour comprendre les mathématiques CM2 - Manuel numérique simple version enseignant - Ed. 2017
# ['CM2->95.9%']
# Maximum : CM2
# ***************
# Via latina Latin  langues et cultures de l'Antiquité 5e 4e 3e (CYCLE 4) Manuel num élève Ed. 2017
# ['5e->99.48%', '4e->99.82%', '3e->99.82%']
# Maximum : 4e
# ***************
# Physique Chimie - Cycle 4 - 2017 - Manuel Numérique Elève - 3 ans-CNS
# ['CM1->98.4%', 'CM2->98.9%', '6e->95.92%', '5e->99.95%', '4e->99.8%', '3e->98.47%']
# Maximum : 5e
# ***************
# Passeurs de textes 2nde - bundle - abonnement 5 ans - adoptant
# ['2de générale et technologique->99.65%']
# Maximum : 2de générale et technologique
# ***************
# Espace-Mots Français CE2 - Edition Export - Manuel numérique enseignant - Ed. 2020
# ['CE2->96.67%']
# Maximum : CE2
# ***************
# Cup of tea CM2 - Manuel numérique enrichi enseignant
# ['CM2->95.7%']
# Maximum : CM2
# ***************
# Management des entreprises BTS 2e année (2017) - Manuel numérique élève
# ['BTS - 1re année->99.22%', 'BTS - 2e année->99.18%']
# Maximum : BTS - 1re année
# ***************
# Fichier numérique enseignant - Litchi CE2 - Edition 2017
# ['CE2->97.29%']
# Maximum : CE2
# ***************
# Projet Voltaire - Parcours Expression - Complet
# ['6e->98.76%', '5e->99.9%', '4e->98.97%', '3e->99.61%', '2de générale et technologique->98.26%']
# Maximum : 5e
# ***************
# Manuel numérique Teen Time anglais cycle 4 / 3e - Licence enrichie élève - éd. 2017
# ['3e->98.96%']
# Maximum : 3e
# ***************
# Ma première Histoire de France
# ['CE2->78.4%', 'CM1->99.9%', 'CM2->99.16%']
# Maximum : CM1
# ***************
# Ressources humaines et Communication Tle STMG (2013) - Manuel numérique enseignant
# ['terminale ST2S->99.97%', 'terminale STD2A->99.79%', 'terminale STI2D->99.96%', 'terminale STL->99.88%', 'terminale techno hôtellerie->98.99%', 'terminale STMG->99.98%', 'terminale TMD->98.92%', 'terminale STHR->99.64%']
# Maximum : terminale STMG
# ***************
# SVT 6e - Coll° C. Lizeaux / R. Tavernier - 2005 - Manuel numérique élève
# ['6e->99.08%']
# Maximum : 6e
# ***************
# Cahier de Français 6e, éd. 2020 - Cahier numérique enseignant
# ['6e->98.99%']
# Maximum : 6e
# ***************
# A portée de mots - Français CM1 - Manuel numérique version enseignant sans adoption - Ed. 2009
# ['CM1->95.14%']
# Maximum : CM1
# ***************
# Que d'histoires ! CP Série 3 - Les pieds dans l'eau - Manuel numérique enseignant
# ['CP->98.27%']
# Maximum : CP
# ***************
# SVT 2de - 2010 - Manuel numérique élève
# ['2de générale et technologique->99.59%']
# Maximum : 2de générale et technologique
# ***************
# Méthode de Singapour – Fichier de l’élève 1 – CE2 (2018) - Manuel numérique élève
# ['CE2->96.97%']
# Maximum : CE2
# ***************
# Perspectives Maths 1re Bac Pro Tertiaire - Manuel numérique - Licence élève enrichie - Ed.2010
# ['1re pro domaine de la production->98.36%', '1re pro domaine des services->98.26%']
# Maximum : 1re pro domaine de la production
# ***************
# MADAME BOVARY
# ['6e->94.47%', '5e->99.9%', '4e->96.43%', '3e->95.52%']
# Maximum : 5e
# ***************
# Manuel numérique enseignant enrichi et personnalisable Prévention Santé Environnement Terminale BAC PRO Ed 2011
# ['terminale pro domaine de la production->98.76%', 'terminale pro domaine des services->98.76%']
# Maximum : terminale pro domaine des services
# ***************
# Cahier d'algorithmique et de programmation Python Bac Pro - Manuel numérique enseignant -  Éd. 2021
# ['2de professionnelle->99.64%']
# Maximum : 2de professionnelle
# ***************
# Management d'un institut - Enseignant BP/Bac Pro Esthétique
# ['2de professionnelle->99.64%']
# Maximum : 2de professionnelle
# ***************
# SES 2de (Ed. num. 2021) - LIB manuel numérique PREMIUM actualisé élève
# ['2de générale et technologique->99.57%']
# Maximum : 2de générale et technologique
# ***************
# Fichier numérique enseignant - Litchi CP - Edition 2016
# ['CP->97.65%']
# Maximum : CP
# ***************
# Reading Time Gulliver in Lilliput CE2 - Manuel numérique enrichi enseignant - Ed. 2013
# ['CE2->96.85%']
# Maximum : CE2
# ***************
# Fantastisch! Lycée 2de -  licence numérique élève
# ['2de générale et technologique->99.71%']
# Maximum : 2de générale et technologique
# ***************
# Soeurs sorcières - Livre 2
# ['5e->98.41%']
# Maximum : 5e
# ***************
# Peter et le mystère du Headless Man (EFL3)
# ['CM1->92.27%', 'CM2->50.26%', '6e->92.16%']
# Maximum : CM1
# ***************
# A portée de mots - Français CE2-CM1 - Manuel numérique simple version élève - Ed. 2013
# ['CE2->90.47%', 'CM1->99.65%', 'CM2->73.53%']
# Maximum : CM1
# ***************
# Ribambelle CP série verte Cahier d'activités 1 éd. 2009 - Manuel interactif
# ['CP->98.33%']
# Maximum : CP
# ***************
# Latitudes 2 niv.A2+ - Manuel numérique enrichi élève
# ['2de générale et technologique->99.47%']
# Maximum : 2de générale et technologique
# ***************
# SES 2de éd. 2014 - Manuel interactif enseignant
# ['2de générale et technologique->99.61%']
# Maximum : 2de générale et technologique
# ***************
# New Enjoy English 5e - Manuel numérique premium enseignant - Pack de 3 clés USB
# ['5e->98.86%']
# Maximum : 5e
# ***************
# Sciences de gestion et numérique - Enseignant Première STMG - Édition 2021
# ['1re STMG->95.43%']
# Maximum : 1re STMG
# ***************
# Histoire et Géographie Enseignement moral et civique - 1e Bac Pro Agricole -  Multisup -GE
# ['1re pro domaine de la production->95.85%', '1re pro domaine des services->95.78%']
# Maximum : 1re pro domaine de la production
# ***************
# Sciences de gestion 1re STMG - Pochette Réflexe STMG i-Manuel  - GE
# ['1re STMG->95.91%']
# Maximum : 1re STMG
# ***************
# Transmath 6e - 2016 - Manuel numérique enseignant licence 1 an
# ['6e->98.76%']
# Maximum : 6e
# ***************
# Techniques esthétiques- Toutes filières esthétique, cosmétique - Parfumerie (2015) - LIB manuel numérique élève
# ['BP - 1re année->78.03%', 'BP - 2e année->78.77%', 'CAP - 1re année->99.91%', 'CAP - 2e année->99.89%', 'BTS - 1re année->99.55%', 'BTS - 2e année->99.5%']
# Maximum : CAP - 1re année
# ***************
# Reporteros 4e - Clé USB
# ['4e->98.78%']
# Maximum : 4e
# ***************
# Outils pour les Maths CE2 - Cahier de géométrie (2015) - Manuel numérique enseignant
# ['CE2->96.92%']
# Maximum : CE2
# ***************
# Version numérique enseignant cahier A mi me encanta espagnol cycle 4 / 5e LV2 - éd. 2016
# ['6e->98.85%', '5e->99.28%', '4e->50.94%', '3e->73.76%']
# Maximum : 5e
# ***************
# Tous lecteurs ! L'aviation Niveau 4 - Complément pédagogique Internet
# ['CE2->50.27%', 'CM1->99.81%', 'CM2->99.74%']
# Maximum : CM1
# ***************
# Je lis avec Mona et ses amis CP - Posters - Manuel numérique enseignant
# ['CP->97.95%']
# Maximum : CP
# ***************
# Le Nouvel A portée de mots - Français CE2 - Manuel numérique simple élève - Ed. 2017
# ['CE2->96.78%']
# Maximum : CE2
# ***************
# Mathématiques 1ère Bac Pro groupements A et B - Manuel numérique élève -  Éd. 2021
# ['1re pro domaine de la production->98.53%', '1re pro domaine des services->98.44%']
# Maximum : 1re pro domaine de la production
# ***************
# Sciences et Techniques Sanitaires et Sociales Tle ST2S (2020) - LIB manuel numérique élève
# ['terminale ST2S->99.97%', 'terminale STD2A->99.81%', 'terminale STI2D->99.96%', 'terminale STL->99.89%', 'terminale techno hôtellerie->98.88%', 'terminale STMG->99.98%', 'terminale TMD->98.82%', 'terminale STHR->99.67%']
# Maximum : terminale STMG
# ***************
# Taoki et compagnie CP - Edition 2017 - Manuel numérique
# ['CP->97.86%']
# Maximum : CP
# ***************
# À moi de lire ! CP (2019) - Pack Manuel d'apprentissage du code + Manuel de lecture - compréhension - Manuel numérique élève
# ['CP->97.64%']
# Maximum : CP
# ***************
# Manuel numérique Kreativ allemand Palier 1 Année 2 - Licence élève - Edition 2014
# ['6e->65.76%', '4e->66.0%', '3e->97.94%']
# Maximum : 3e
# ***************
# Together 4e - Manuel numérique enrichi enseignant
# ['4e->98.77%']
# Maximum : 4e
# ***************
# Ressources humaines et Communication Tle STMG (2013) - Manuel numérique élève
# ['terminale ST2S->99.97%', 'terminale STD2A->99.79%', 'terminale STI2D->99.96%', 'terminale STL->99.89%', 'terminale techno hôtellerie->98.98%', 'terminale STMG->99.98%', 'terminale TMD->98.91%', 'terminale STHR->99.64%']
# Maximum : terminale STMG
# ***************
# Gestion de l'entrepôt seconde professionnelle version élève
# ['2de générale et technologique->99.54%']
# Maximum : 2de générale et technologique
# ***************
# Droit 1re STMG (2021) - FLEX manuel numérique granulaire élève
# ['1re STD2A->99.78%', '1re STI2D->99.95%', '1re STL->99.81%', '1re STMG->99.92%', '1re ST2S->99.97%', '1re techno hôtellerie->97.78%', '1re TMD->97.79%', '1re STHR->99.17%']
# Maximum : 1re ST2S
# ***************
# Mathématiques BTS industriels (2014) - Manuel numérique élève
# ['BTS - 1re année->99.34%', 'BTS - 2e année->99.28%']
# Maximum : BTS - 1re année
# ***************
# Manuel numérique en ligne Dossiers et études Économie Droit Seconde professionnelle Bac pro tertiaires - Élève adoptant manuel papier
# ['2de professionnelle->99.58%']
# Maximum : 2de professionnelle
# ***************
# Wanderlust Allemand 2de 2019 Manuel num élève Licence 5ans Online Adoptant papier
# ['2de générale et technologique->99.6%']
# Maximum : 2de générale et technologique
# ***************
# Mots en herbe CE1 2016 élève 1 an
# ['CE1->96.74%']
# Maximum : CE1
# ***************
# En Voz Alta Tle - Manuel numérique premium enseignant
# ['terminale générale->78.73%', 'terminale ST2S->84.53%', 'terminale STI2D->72.16%', 'terminale STMG->99.85%']
# Maximum : terminale STMG
# ***************
# Perspectives - DROIT-ECONOMIE - 1re STMG, Éd. 2021 - Manuel numérique élève actualisé
# ['1re STMG->94.67%']
# Maximum : 1re STMG
# ***************
# Technologie Collège
# ['CM1->56.95%', 'CM2->74.66%', '6e->99.97%', '5e->99.59%', '4e->98.67%', '3e->99.77%']
# Maximum : 6e
# ***************
# Les Nouveaux Outils pour le Français CE1 - Fichier (2015) - Manuel numérique enseignant
# ['CE1->96.23%']
# Maximum : CE1
# ***************
# Economie-Droit 1re et Tle Bac Pro (2014) - Manuel numérique élève
# ['terminale pro domaine de la production->98.77%', 'terminale pro domaine des services->98.79%']
# Maximum : terminale pro domaine des services
# ***************
# Manuel numérique Histoire-Géographie-EMC cycle 4 / 4e - Licence enseignant enrichie - Ed 2016
# ['4e->98.84%']
# Maximum : 4e
# ***************
# Français 2e pro ed 2013 - Manuel numérique - Licence enseignant
# ['2de professionnelle->99.48%']
# Maximum : 2de professionnelle
# ***************
# Outils pour le Français CM1 (2019) - Manuel numérique enseignant
# ['CM1->93.51%']
# Maximum : CM1
# ***************
# Droit 1re STMG (2019) Manuel - LIB manuel numérique enseignant
# ['1re STD2A->99.78%', '1re STI2D->99.95%', '1re STL->99.81%', '1re STMG->99.93%', '1re ST2S->99.97%', '1re techno hôtellerie->97.88%', '1re TMD->97.89%', '1re STHR->99.2%']
# Maximum : 1re ST2S
# ***************
# Les Chemins de la Pensée Philosophie Tle 2020 Manuel numérique élève Licence 100% numérique
# ['terminale générale->99.39%', 'terminale ST2S->99.99%', 'terminale STD2A->99.92%', 'terminale STI2D->99.98%', 'terminale STL->99.91%', 'terminale techno hôtellerie->99.74%', 'terminale STMG->100.0%', 'terminale TMD->99.74%', 'terminale STHR->99.76%']
# Maximum : terminale STMG
# ***************
# Manuel numérique Sciences de la Vie et de la Terre 2de - Licence élève - Edition 2010
# ['2de générale et technologique->99.64%']
# Maximum : 2de générale et technologique
# ***************
# Économie Droit 2de Bac Pro (2015) - Manuel numérique élève
# ['2de professionnelle->66.11%']
# Maximum : 2de professionnelle
# ***************
# SES 2de Fichier d'activités - Version numérique enseignant - Ed. 2021
# ['2de générale et technologique->99.65%']
# Maximum : 2de générale et technologique
# ***************
# SVT 6e - Cahiers de révisions
# ['6e->98.97%']
# Maximum : 6e
# ***************
# Manuel numérique enrichi Mercatique Terminale STMG - Élève non adoptant manuel papier
# ['terminale STMG->95.76%']
# Maximum : terminale STMG
# ***************
# Cahier connecté SVT cycle 4 ed 2017 - Offres pour la classe
# ['5e->99.71%', '4e->99.88%', '3e->99.59%']
# Maximum : 4e
# ***************
# Histoire-Géographie EMC 6e éd. 2016 - Manuel numérique enrichi élève
# ['6e->98.87%']
# Maximum : 6e
# ***************
# Passard & Perl SES 2de 2016 enseignant adopant numérique 5ans
# ['2de générale et technologique->99.65%']
# Maximum : 2de générale et technologique
# ***************
# CAP Agent Polyvalent de Restauration - CAP Agent Polyvalent de Restauration - élève
# ['CAP - 1re année->99.18%', 'CAP - 2e année->99.13%']
# Maximum : CAP - 1re année
# ***************
# Commercialisation et services CAP CSHCR (2018) - Manuel numérique enseignant
# ['CAP - 1re année->98.84%', 'CAP - 2e année->98.75%']
# Maximum : CAP - 1re année
# ***************
# HGGSP Tle (Ed. num. 2021) - Lib manuel numérique PREMIUM actualisé + banque de ressources enseignant
# ['terminale générale->99.25%']
# Maximum : terminale générale
# ***************
# Histoire 2nde ed 2010 - Manuel numérique - Autres offres
# ['2de générale et technologique->99.59%']
# Maximum : 2de générale et technologique
# ***************
# Manuel numérique élève simple et personnalisable Economie-Droit Terminale BAC PRO Ed 2012
# ['terminale pro domaine de la production->98.81%', 'terminale pro domaine des services->98.82%']
# Maximum : terminale pro domaine des services
# ***************
# S1 Prospection et suivi clientèle / S4 Mercatique - 1RE ET TLE Élève BAC PRO Vente
# ['terminale pro domaine de la production->99.76%', 'terminale pro domaine des services->99.74%', '1re pro domaine de la production->99.55%', '1re pro domaine des services->99.6%']
# Maximum : terminale pro domaine de la production
# ***************
# Biologie et Physiopathologies humaines Tle ST2S (2015) - Manuel numérique enseignant
# ['terminale ST2S->99.97%', 'terminale STD2A->99.8%', 'terminale STI2D->99.96%', 'terminale STL->99.89%', 'terminale techno hôtellerie->98.92%', 'terminale STMG->99.98%', 'terminale TMD->98.88%', 'terminale STHR->99.63%']
# Maximum : terminale STMG
# ***************
# Compétences et évaluations interactives en Histoire-Géo EMC - 3e - CNS  (Viascola)-Offre 6 mois+2
# ['CM1->99.32%', 'CM2->98.83%', '6e->99.67%', '5e->99.97%', '4e->99.77%', '3e->99.17%']
# Maximum : 5e
# ***************
# Economie et Gestion Hôtelière 1re/Tle
# ['1re STHR->51.31%', 'terminale STHR->60.06%']
# Maximum : terminale STHR
# ***************
# Espagnol 2de - Manuel numérique enseignant simple - Ed. 2015
# ['2de générale et technologique->99.56%']
# Maximum : 2de générale et technologique
# ***************
# Litchi Mathématiques CP - Fichier élève numérique version élève - Ed. 2019
# ['CP->96.91%']
# Maximum : CP
# ***************
# Nuevas Voces 2de - Manuel numérique premium enseignant - Clé USB
# ['2de générale et technologique->99.6%']
# Maximum : 2de générale et technologique
# ***************
# En situation Management des organisations TERM STMG - Manuel numérique enseignant simple - Éd. 2016
# ['terminale STMG->93.72%']
# Maximum : terminale STMG
